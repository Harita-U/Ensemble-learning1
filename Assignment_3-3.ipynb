# %%
#Import the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
import numpy as np
# %matplotlib inline
from sklearn.model_selection import train_test_split
from scipy.stats import zscore
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix,classification_report

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('/content/Parkinson_data.csv')

# %%
data.tail(10)
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...   spread2        D2       PPE
# 185  phon_R01_S49_3      116.286       177.291  ...  0.133917  2.058658  0.214346
# 186  phon_R01_S49_4      116.556       592.030  ...  0.153310  2.161936  0.120605
# 187  phon_R01_S49_5      116.342       581.289  ...  0.116636  2.152083  0.138868
# 188  phon_R01_S49_6      114.563       119.167  ...  0.149694  1.913990  0.121777
# 189  phon_R01_S50_1      201.774       262.707  ...  0.159890  2.316346  0.112838
# 190  phon_R01_S50_2      174.188       230.978  ...  0.121952  2.657476  0.133050
# 191  phon_R01_S50_3      209.516       253.017  ...  0.129303  2.784312  0.168895
# 192  phon_R01_S50_4      174.688       240.005  ...  0.158453  2.679772  0.131728
# 193  phon_R01_S50_5      198.764       396.961  ...  0.207454  2.138608  0.123306
# 194  phon_R01_S50_6      214.289       260.277  ...  0.190667  2.555477  0.148569
#
# [10 rows x 24 columns]

# %%
data.isnull().values.any() ## For checking nay null values
# Out:
# False

# %%
data.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...          D2         PPE
# count   195.000000    195.000000  ...  195.000000  195.000000
# mean    154.228641    197.104918  ...    2.381826    0.206552
# std      41.390065     91.491548  ...    0.382799    0.090119
# min      88.333000    102.145000  ...    1.423287    0.044539
# 25%     117.572000    134.862500  ...    2.099125    0.137451
# 50%     148.790000    175.829000  ...    2.361532    0.194052
# 75%     182.769000    224.205500  ...    2.636456    0.252980
# max     260.105000    592.030000  ...    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
data.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...        D2       PPE
# MDVP:Fo(Hz)          1.000000      0.400985  ...  0.177980 -0.372356
# MDVP:Fhi(Hz)         0.400985      1.000000  ...  0.176323 -0.069543
# MDVP:Flo(Hz)         0.596546      0.084951  ... -0.100629 -0.340071
# MDVP:Jitter(%)      -0.118003      0.102086  ...  0.433434  0.721543
# MDVP:Jitter(Abs)    -0.382027     -0.029198  ...  0.310694  0.748162
# MDVP:RAP            -0.076194      0.097177  ...  0.426605  0.670999
# MDVP:PPQ            -0.112165      0.091126  ...  0.412524  0.769647
# Jitter:DDP          -0.076213      0.097150  ...  0.426556  0.671005
# MDVP:Shimmer        -0.098374      0.002281  ...  0.507088  0.693771
# MDVP:Shimmer(dB)    -0.073742      0.043465  ...  0.512233  0.695058
# Shimmer:APQ3        -0.094717     -0.003743  ...  0.467265  0.645377
# Shimmer:APQ5        -0.070682     -0.009997  ...  0.502174  0.702456
# MDVP:APQ            -0.077774      0.004937  ...  0.536869  0.721694
# ...

# %%
sns.pairplot(data)

# %%
Y=data["status"]
X=data.drop("status",axis=1)
X=data.drop("name",axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.3,random_state=100)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver = 'lbfgs', multi_class= 'multinomial')
#lr = LogisticRegression(solver = '', multi_class= 'multinomial')
lr.fit(X_train, y_train)

# %%
y_pred=lr.predict(X_test)

# %%
print(f"Accuracy of logistic regression model = {lr.score(X_test,y_test)}")

# %%
type(y_pred)

# %%
# calculate accuracy measures and confusion matrix
from sklearn import metrics

print("Confusion Matrix")
cm = metrics.confusion_matrix(y_test,y_pred)

df_cm = pd.DataFrame(cm, index = [i for i in ["1","0"]],
                  columns = [i for i in ["Predict 1","Predict 0"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True)
plt.title("Confusion matrix for Logistic Regression")

# %%
df_table = confusion_matrix(y_test,y_pred)
a_logistic = (df_table[0,0] + df_table[1,1]) / (df_table[0,0] + df_table[0,1] + df_table[1,0] + df_table[1,1])# Accuracy
p_logistic = df_table[1,1] / (df_table[1,1] + df_table[0,1])# Precision
r_logistic = df_table[1,1] / (df_table[1,1] + df_table[1,0])# Recall
f_logistic = (2 * p_logistic * r_logistic) / (p_logistic + r_logistic)# f-score   

print("accuracy of Logistic Regression: ",round(a_logistic,2))
print("precision of Logistic Regression: ",round(p_logistic,2))
print("recall of Logistic Regression: ",round(r_logistic,2))
print("F1 score of Logistic Regression : ",round(f_logistic,2))

# %%
#Checking Naive bayes model

# %%
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X,Y,test_size=0.3,random_state=100)

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train1, y_train1)

# %%
y_pred1=nb.predict(X_test)

# %%
type(y_test1)

# %%
print(f"The accuracy of GaussianNaive Bayes is: {nb.score(X_test1,y_test1)}")

# %%
from sklearn import metrics

cm = metrics.confusion_matrix(y_test,y_pred)

df_cm = pd.DataFrame(cm, index = [i for i in ["1","0"]],
                  columns = [i for i in ["Predict 1","Predict 0"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True)
plt.title("Confusion matrix for Naive Model")

# %%
df_table = confusion_matrix(y_test,y_pred)
a_naivebayes = (df_table[0,0] + df_table[1,1]) / (df_table[0,0] + df_table[0,1] + df_table[1,0] + df_table[1,1])# Accuracy
p_naivebayes = df_table[1,1] / (df_table[1,1] + df_table[0,1])# Precision
r_naivebayes = df_table[1,1] / (df_table[1,1] + df_table[1,0])# Recall
f_naivebayes = (2 * p_naivebayes * r_naivebayes) / (p_naivebayes + r_naivebayes)# f-score   

print("accuracy of Naive Bayes: ",round(a_naivebayes,2))
print("precision of Naive Bayes: ",round(p_naivebayes,2))
print("recall of Naive Bayes: ",round(r_naivebayes,2))
print("F1 score of Naive Bayes : ",round(f_naivebayes,2))

# %%
## KNN

# %%
from sklearn.model_selection import train_test_split

X_train2, X_test2, y_train2, y_test2 = train_test_split(X,Y,test_size=0.3,random_state=100)

# %%
# loading library
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# creating odd list of K for KNN
myList = list(range(1,20))

# subsetting just the odd ones
neighbors = list(filter(lambda x: x % 2 != 0, myList))

# %%
# empty list that will hold accuracy scores
ac_scores = []

# perform accuracy metrics for values from 1,3,5....19
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    # predict the response
    y_pred = knn.predict(X_test)
    # evaluate accuracy
    scores = accuracy_score(y_test, y_pred)
    ac_scores.append(scores)

# changing to misclassification error
MSE = [1 - x for x in ac_scores]

# determining best k
optimal_k = neighbors[MSE.index(min(MSE))]
print("The optimal number of neighbors is %d" % optimal_k)

# %%
import matplotlib.pyplot as plt
# plot misclassification error vs k
plt.plot(neighbors, MSE)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Misclassification Error')
plt.show()

# %%
# loading library
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# instantiate learning model (Optimal value of k selected form above condition)
knn = KNeighborsClassifier(n_neighbors = optimal_k)

# fitting the model
knn.fit(X_train, y_train)

# predict the response
y_pred = knn.predict(X_test)

# evaluate accuracy
#print("Thw accuracy score of KNN for optimal value of k is %d",%accuracy_score(y_test, y_pred))

# %%
df_table = confusion_matrix(y_test2,y_pred)
a_knn= (df_table[0,0] + df_table[1,1]) / (df_table[0,0] + df_table[0,1] + df_table[1,0] + df_table[1,1])
p_knn = df_table[1,1] / (df_table[1,1] + df_table[0,1])
r_knn = df_table[1,1] / (df_table[1,1] + df_table[1,0])
f_knn= (2 * p_knn* r_knn) / (p_knn + r_knn)

print("accuracy of KNN model : ",round(a_knn,2))
print("precision of KNN model: ",round(p_knn,2))
print("recall of KNN model: ",round(r_knn,2))
print("F1 scoreof KNN model: ",round(f_knn,2))

# %%
## SVC model

# %%
from sklearn.model_selection import train_test_split

X_train3, X_test3, y_train3, y_test3 = train_test_split(X,Y,test_size=0.3,random_state=100)

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train3, y_train3)

print("Accuracy on training set: {:.2f}".format(svc.score(X_train3, y_train3)))
print("Accuracy on test set: {:.2f}".format(svc.score(X_test3, y_test3)))

# %%
y_pred3 = knn.predict(X_test3)

# %%
df_table = confusion_matrix(y_test3,y_pred3)
a_svc= (df_table[0,0] + df_table[1,1]) / (df_table[0,0] + df_table[0,1] + df_table[1,0] + df_table[1,1])
p_svc = df_table[1,1] / (df_table[1,1] + df_table[0,1])
r_svc = df_table[1,1] / (df_table[1,1] + df_table[1,0])
f_svc= (2 * p_svc* r_svc) / (p_svc + r_svc)

print("accuracy of SVC model : ",round(a_svc,2))
print("precision of SVC model: ",round(p_svc,2))
print("recall of SVC model: ",round(r_svc,2))
print("F1 scoreof SVC model: ",round(f_svc,2))

# %%
Result_models=pd.DataFrame(data={'Model':['Accuracy','Precision','Recall','F-1 score'],'Logistic':[a_logistic,p_logistic,r_logistic,f_logistic],
                                 'Naive Bayes':[a_naivebayes,p_naivebayes,r_naivebayes,f_naivebayes],
                                 'KNN':[a_knn,p_knn,r_knn,f_knn],'SVC':[a_svc,p_svc,r_svc,f_svc]})
Result_models

# %% [markdown]
# Logistic Regression and Naive bayes work equally well here in the Parkinson data set

# %% [markdown]
# ## Stacking Classifier

# %%
data=pd.read_csv('/content/Parkinson_data.csv')

# %%
Y=data["status"]
X=data.drop("status",axis=1)
X=data.drop("name",axis=1)

# %%
from mlxtend.classifier import StackingClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB 
from sklearn.ensemble import RandomForestClassifier

# %%
clf1 = KNeighborsClassifier(n_neighbors=1)
clf2 = LogisticRegression() # RandomForestClassifier(random_state=1)
clf3 = GaussianNB()
clf4 = RandomForestClassifier(random_state=1)
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
rf = RandomForestClassifier(random_state=1) # LogisticRegression()

# %%
sclf = StackingClassifier(classifiers=[clf1, clf2, clf3, clf4], meta_classifier = rf)

# %%
for clf, label in zip([clf1,clf2,clf3,clf4,sclf], ['KNN', 'LR', 'Naive Bayes', 'RF',
                                                 'StackingClassifier']):
    scores = model_selection.cross_val_score(clf, X, Y, cv=10, scoring='accuracy')
    print("Accuracy: %0.2f (+/- %0.2f) [%s]"  % (scores.mean(), scores.std(), label))
